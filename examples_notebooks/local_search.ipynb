# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.input.loaders.dfs import (
    store_entity_semantic_embeddings,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.question_gen.local_gen import LocalQuestionGen
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

# %% [markdown]
# ## Local Search Example
#
# Local search method generates answers by combining relevant data from the AI-extracted knowledge-graph with text chunks of the raw documents. This method is suitable for questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?).

# %% [markdown]
# ### Load text units and graph data tables as context for local search
#
# - In this test we first load indexing outputs from parquet files to dataframes, then convert these dataframes into collections of data objects aligning with the knowledge model.

# %% [markdown]
# ### Load tables to dataframes

# %%
INPUT_DIR = "./inputs/operation dulce"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %% [markdown]
# #### Read entities

# %%
# read nodes table to get community and degree data
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

# load description embeddings to an in-memory lancedb vectorstore
# to connect to a remote db, specify url and port values.
description_embedding_store = LanceDBVectorStore(
    collection_name="entity_description_embeddings",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
entity_description_embeddings = store_entity_semantic_embeddings(
    entities=entities, vectorstore=description_embedding_store
)

print(f"Entity count: {len(entity_df)}")
entity_df.head()
# Out:
# Entity count: 434
#    level                      title          type  \
# 0      0                ALEX MERCER        PERSON
# 1      0                TAYLOR CRUZ        PERSON
# 2      0               JORDAN HAYES        PERSON
# 3      0                 SAM RIVERA        PERSON
# 4      0  PARANORMAL MILITARY SQUAD  ORGANIZATION
#
#                                          description  \
# 0  Alex Mercer is a character with a military bac...
# 1  Taylor Cruz is a character who plays a pivotal...
# 2  Dr. Jordan Hayes is a key character in a narra...
# 3  Sam Rivera is a character renowned for their t...
# 4  The Paranormal Military Squad is an elite clan...
#
#                                            source_id community  degree  \
# 0  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1       9
# 1  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      12
# 2  00fafabae48948779fee2afe600f5143,2cf7a230c367a...         1       9
# 3  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      15
# 4  00fafabae48948779fee2afe600f5143,1e433d6b30887...         1      14
#
#    human_readable_id                                id  size graph_embedding  \
# 0                  0  b45241d70f0e43fca764df95b2b81f77     9            None
# 1                  1  4119fd06010c494caa07f439b333f4c5    12            None
# 2                  2  d3835bf3dda84ead99deadbeac5d0d7d     9            None
# 3                  3  077d2820ae1845bcbb1803379a3d1eae    15            None
# 4                  4  3671ea0dd4e84c1a9b02c5ab2c8f4bac    14            None
#
#   entity_type                 top_level_node_id  x  y
# 0        None  b45241d70f0e43fca764df95b2b81f77  0  0
# 1        None  4119fd06010c494caa07f439b333f4c5  0  0
# 2        None  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3        None  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4        None  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0

# %% [markdown]
# #### Read relationships

# %%
relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

print(f"Relationship count: {len(relationship_df)}")
relationship_df.head()
# Out:
# Relationship count: 276
#         source        target  weight  \
# 0  ALEX MERCER   TAYLOR CRUZ     7.0
# 1  ALEX MERCER   TAYLOR CRUZ     7.0
# 2  ALEX MERCER   TAYLOR CRUZ     7.0
# 3  ALEX MERCER   TAYLOR CRUZ     7.0
# 4  ALEX MERCER  JORDAN HAYES     6.0
#
#                                          description  \
# 0  Alex Mercer and Taylor Cruz are integral membe...
# 1  Alex Mercer and Taylor Cruz are integral membe...
# 2  Alex Mercer and Taylor Cruz are integral membe...
# 3  Alex Mercer and Taylor Cruz are integral membe...
# 4  Alex Mercer and Jordan Hayes are colleagues wh...
#
#                                        text_unit_ids  \
# 0  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 1  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 2  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 3  [00fafabae48948779fee2afe600f5143, 1e433d6b308...
# 4  [00fafabae48948779fee2afe600f5143, 2cf7a230c36...
#
#                                  id human_readable_id  source_degree  \
# 0  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 1  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 2  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 3  b35c3d1a7daa4924b6bdb58bc69c354d                 0              9
# 4  a97e2ecd870944cfbe71c79bc0fcc752                 1              9
#
#    target_degree  rank
# 0             12    21
# 1             12    21
# 2             12    21
# 3             12    21
# 4              9    18

# %%
covariate_df = pd.read_parquet(f"{INPUT_DIR}/{COVARIATE_TABLE}.parquet")

claims = read_indexer_covariates(covariate_df)

print(f"Claim records: {len(claims)}")
covariates = {"claims": claims}
# Out:
# Claim records: 89

# %% [markdown]
# #### Read community reports

# %%
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)

print(f"Report records: {len(report_df)}")
report_df.head()
# Out:
# Report records: 6
#   community                                       full_content  level  rank  \
# 0         4  # Dulce Base and the Paranormal Military Squad...      1   8.5
# 1         5  # Sam Rivera and the Paranormal Military Squad...      1   7.5
# 2         0  # Dulce Base and the Paranormal Military Squad...      0   8.5
# 3         1  # Dulce Base and the Paranormal Military Squad...      0   8.5
# 4         2  # Dulce Base: Extraterrestrial Research and Co...      0   8.5
#
#                                                title  \
# 0  Dulce Base and the Paranormal Military Squad: ...
# 1  Sam Rivera and the Paranormal Military Squad a...
# 2  Dulce Base and the Paranormal Military Squad Team
# 3  Dulce Base and the Paranormal Military Squad: ...
# 4  Dulce Base: Extraterrestrial Research and Comm...
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is high due to the ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is high due to the ...
# 4  The impact severity rating is high due to the ...
#
#                                              summary  \
# 0  The community is centered around Dulce Base, a...
# 1  The community is centered around Sam Rivera, a...
# 2  Dulce Base serves as the operational hub for t...
# 3  The community is centered around Dulce Base, a...
# 4  Dulce Base is a highly classified facility in ...
#
#                                             findings  \
# 0  [{'explanation': 'Dulce Base is the primary lo...
# 1  [{'explanation': 'Sam Rivera is recognized for...
# 2  [{'explanation': 'The Paranormal Military Squa...
# 3  [{'explanation': 'Sam Rivera is recognized for...
# 4  [{'explanation': 'Dulce Base is the epicenter ...
#
#                                    full_content_json  \
# 0  {\n    "title": "Dulce Base and the Paranormal...
# 1  {\n    "title": "Sam Rivera and the Paranormal...
# 2  {\n    "title": "Dulce Base and the Paranormal...
# 3  {\n    "title": "Dulce Base and the Paranormal...
# 4  {\n    "title": "Dulce Base: Extraterrestrial ...
#
#                                      id
# 0  6f8ba6b6-506e-46c1-83ce-982d59622554
# 1  418f4536-d673-4212-8a7c-ca1aac547d0f
# 2  251df57e-fd49-49a7-b262-ccaff95d7a51
# 3  6e536385-8056-4a82-8670-c0ccaf007fb4
# 4  660c8fba-b65f-4fcd-9c98-203600cf1981

# %% [markdown]
# #### Read text units

# %%
text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

print(f"Text unit records: {len(text_unit_df)}")
text_unit_df.head()
# Out:
# Text unit records: 12
#                                  id  \
# 0  2cf7a230c367a2dfaf0fc3c903eb8948
# 1  6d1255303acb7c9dc951cb0f5fc3042c
# 2  e841f178310356740b2ee9101d12c97f
# 3  f36d96862b9366d7240b5c7ceb04f12b
# 4  f7d43808d2fb452cd953bf50c6de6bd4
#
#                                                 text  n_tokens  \
# 0  # Operation: Dulce\n\n## Chapter 1\n\nThe thru...      2500
# 1   be the same.\n\n\*\n\nThe sense of foreboding...      2500
# 2  . "Your take on these signal inconsistencies?"...      2500
# 3  , absorbed in the bewilderment of contact, whi...      2500
# 4   were at once coherent and enigmatic: "*Voyage...      2500
#
#                          document_ids  \
# 0  [958fdd043f17ade63cb13570b59df295]
# 1  [958fdd043f17ade63cb13570b59df295]
# 2  [958fdd043f17ade63cb13570b59df295]
# 3  [958fdd043f17ade63cb13570b59df295]
# 4  [958fdd043f17ade63cb13570b59df295]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 2  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 3  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 4  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
#
#                                     relationship_ids  \
# 0  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 1  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 2  [b35c3d1a7daa4924b6bdb58bc69c354d, a97e2ecd870...
# 3  [b35c3d1a7daa4924b6bdb58bc69c354d, 09f18f81442...
# 4  [e02be3e37ca0454883a4c1fd859c24bb, 1dbc51475cb...
#
#                                        covariate_ids
# 0  [ad5a2020-cdec-4982-acdf-dbe5ee530066, 9d8a0fe...
# 1  [5d1c9126-c48d-4755-9f9c-f739c823f95f, ec64a42...
# 2  [0b22a34b-32e9-46a4-a0e8-d3d5466eba15, 7e14972...
# 3  [9cd6d645-ab97-4b39-b02e-647cea9b5545, 50dc124...
# 4             [87cf5900-6211-4e04-9115-50f3617c88b4]

# %%
from dotenv import load_dotenv
load_dotenv()

api_key = os.environ["AZURE_OPENAI_API_KEY"]
llm_model = os.environ["AZURE_OPENAI_Deployment"]
embedding_model = "text-embedding-ada-002"
endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]

llm = ChatOpenAI(
    api_version="2024-02-15-preview",
    api_key=api_key,
    api_base=endpoint,
    model=llm_model,
    api_type=OpenaiApiType.AzureOpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_version="2024-02-15-preview",
    api_key=api_key,
    api_base=endpoint,
    api_type=OpenaiApiType.AzureOpenAI,
    model=embedding_model,
    deployment_name=embedding_model,
    max_retries=20,
)

# %% [markdown]
# ### Create local search context builder

# %%
context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    covariates=covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

# %% [markdown]
# ### Create local search engine

# %%
# text_unit_prop: proportion of context window dedicated to related text units
# community_prop: proportion of context window dedicated to community reports.
# The remaining proportion is dedicated to entities and relationships. Sum of text_unit_prop and community_prop should be <= 1
# conversation_history_max_turns: maximum number of turns to include in the conversation history.
# conversation_history_user_turns_only: if True, only include user queries in the conversation history.
# top_k_mapped_entities: number of related entities to retrieve from the entity description embedding store.
# top_k_relationships: control the number of out-of-network relationships to pull into the context window.
# include_entity_rank: if True, include the entity rank in the entity table in the context window. Default entity rank = node degree.
# include_relationship_weight: if True, include the relationship weight in the context window.
# include_community_rank: if True, include the community rank in the context window.
# return_candidate_context: if True, return a set of dataframes containing all candidate entity/relationship/covariate records that
# could be relevant. Note that not all of these records will be included in the context window. The "in_context" column in these
# dataframes indicates whether the record is included in the context window.
# max_tokens: maximum number of tokens to use for the context window.


local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

# %%
search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %% [markdown]
# ### Run local search on sample queries

# %%
result = await search_engine.asearch("Tell me about Agent Mercer")
print(result.response)
# Out:
# ## Overview of Agent Alex Mercer
#
# Agent Alex Mercer is a central figure within the Paranormal Military Squad Team at Dulce Base. His role is multifaceted, encompassing leadership, strategic oversight, and direct involvement in the analysis and interpretation of extraterrestrial signals. Mercer's background in military service equips him with the skills necessary to navigate the complexities of interspecies communication and the operational demands of Dulce Base's command center [Data: Entities (0, 209, 143)].
#
# ## Leadership and Responsibilities
#
# As a leader, Mercer is responsible for guiding the Paranormal Military Squad through the intricacies of their mission, which includes establishing contact with extraterrestrial intelligence. His leadership is characterized by a balanced approach that combines caution with strategic foresight. Mercer is deeply involved in overseeing the team's efforts to decode alien messages and ensure that their responses are both thoughtful and measured [Data: Relationships (5, 8, 7); Claims (50, 57, 67, 82)].
#
# ## Key Relationships
#
# Mercer's effectiveness as a leader is bolstered by his strong relationships with key team members. He works closely with Dr. Jordan Hayes, whose expertise in deciphering alien code is crucial to the mission's success. Their collaboration is marked by mutual respect and a shared commitment to understanding extraterrestrial signals [Data: Relationships (1, 4, 26, 67)]. Additionally, Mercer interacts with other team members such as Sam Rivera and Taylor Cruz, whose technical and strategic contributions are vital to the squad's objectives [Data: Relationships (2, 0, 18)].
#
# ## Psychological and Emotional Complexity
#
# Mercer's role is not without its psychological and emotional challenges. His compliance in the briefing room and discussions about intuition and trust reveal the depth of his involvement and the complexities of the mission. Mercer shares concerns with his colleagues about the larger implications of their work, indicating a nuanced understanding of the potential risks and rewards of their endeavors [Data: Claims (1, 8, 9, 85)].
#
# ## Contributions to the Mission
#
# Mercer's contributions extend beyond leadership and strategy. He is actively involved in the decryption and analysis of alien signals, a task that requires both analytical skills and a deep understanding of extraterrestrial patterns. His efforts are crucial in interpreting the alien messages and ensuring that the team's responses are appropriate and effective [Data: Claims (73, 85, 22, 37, 41, 45)].
#
# ## Conclusion
#
# Agent Alex Mercer is a pivotal figure within the Paranormal Military Squad Team at Dulce Base. His leadership, strategic oversight, and direct involvement in the analysis of extraterrestrial signals make him an indispensable member of the team. Through his strong relationships with key team members and his balanced approach to the mission, Mercer exemplifies the qualities necessary to navigate the complexities of interspecies communication and the operational demands of Dulce Base [Data: Entities (0, 209); Relationships (5, 1, 4, 2, 0); Claims (50, 57, 67, 82, 85)].

# %%
question = "Tell me about Dr. Jordan Hayes"
result = await search_engine.asearch(question)
print(result.response)
# Out:
# # Dr. Jordan Hayes
#
# ## Overview
#
# Dr. Jordan Hayes is a pivotal member of the Paranormal Military Squad Team stationed at Dulce Base. Their primary role involves deciphering alien code and interpreting extraterrestrial patterns, which are crucial for the team's mission of understanding and interacting with extraterrestrial entities [Data: Entities (104, 2); Relationships (22, 40, 64)].
#
# ## Expertise and Contributions
#
# Dr. Hayes brings a wealth of expertise to the team, particularly in the areas of decryption algorithms and signal analysis. Their analytical mindset and methodical approach are essential for isolating signal harmonics and decrypting alien messages, which are key components of the team's efforts to communicate with alien intelligence [Data: Entities (2, 148, 166, 180, 192)]. Dr. Hayes' work is not just about understanding the alien signals but also about interpreting them to gain insights into extraterrestrial thought patterns and potential threats or wisdom [Data: Claims (49, 74, 84)].
#
# ## Key Relationships
#
# Dr. Hayes collaborates closely with several team members, most notably Agent Alex Mercer. Their partnership is built on mutual respect and a shared focus on deciphering alien signals and managing interspecies communication [Data: Relationships (1, 4, 26, 67)]. This collaboration is crucial for the success of their mission, as both bring complementary skills to the table. Additionally, Dr. Hayes works with other colleagues like Sam Rivera and Taylor Cruz, further emphasizing the team's collective effort in their groundbreaking work [Data: Relationships (9, 15, 21, 34)].
#
# ## Mission and Impact
#
# The mission of the Paranormal Military Squad Team has evolved from mere observation to active engagement and preparation for communal outreach beyond the stars. Dr. Hayes' role in this mission is critical, as their work on deciphering alien code and interpreting first contact data could mark the beginning of a new era in human-alien relations [Data: Claims (46, 58, 59, 83, 88)]. The discovery of hidden technology and the analysis of evolving alien signals suggest that Dr. Hayes is on the verge of a scientific breakthrough that could have far-reaching implications [Data: Claims (18, 49, 74)].
#
# ## Analytical Mindset
#
# Known for their analytical and skeptical nature, Dr. Hayes places a strong emphasis on empirical evidence and adaptability in the face of the unknown. This skepticism is particularly evident when the team descends into an underground facility, where Dr. Hayes reflects on the potential data and evidence that could be found there, while remaining cautious about non-empirical possibilities [Data: Claims (12, 13, 26, 36, 39)].
#
# ## Conclusion
#
# Dr. Jordan Hayes is a central figure in the Paranormal Military Squad Team's efforts to understand and interact with extraterrestrial entities. Their expertise in decryption algorithms, signal analysis, and extraterrestrial patterns, combined with their analytical mindset and collaborative spirit, make them an invaluable asset to the team. As humanity stands on the brink of interstellar exploration, Dr. Hayes' contributions could play a crucial role in shaping the future of human-alien relations [Data: Entities (104, 2); Relationships (22, 40, 64); Claims (46, 58, 59, 83, 88)].

# %% [markdown]
# #### Inspecting the context data used to generate the response

# %%
result.context_data["entities"].head()
# Out:
#     id            entity                                        description  \
# 0  104  DR. JORDAN HAYES  Dr. Jordan Hayes is a member of the Paranormal...
# 1  153         EXPERTISE  The specialized knowledge or skill that team m...
# 2    2      JORDAN HAYES  Dr. Jordan Hayes is a key character in a narra...
# 3  148     DATA ANALYSIS  The process of examining and interpreting info...
# 4  140   STAR ALIGNMENTS  Celestial configurations that Dr. Jordan Hayes...
#
#   number of relationships  in_context
# 0                       7        True
# 1                       0        True
# 2                       9        True
# 3                       0        True
# 4                       0        True

# %%
result.context_data["relationships"].head()
# Out:
#    id                     source                     target  \
# 0  21               JORDAN HAYES                 SAM RIVERA
# 1  22               JORDAN HAYES  PARANORMAL MILITARY SQUAD
# 2  34                 SAM RIVERA           DR. JORDAN HAYES
# 3   9                TAYLOR CRUZ               JORDAN HAYES
# 4  40  PARANORMAL MILITARY SQUAD           DR. JORDAN HAYES
#
#                                          description weight rank links  \
# 0  Jordan Hayes and Sam Rivera are colleagues at ...    5.0   24     2
# 1  Jordan Hayes is a member of the Paranormal Mil...    5.0   23     2
# 2  Dr. Jordan Hayes and Sam Rivera are colleagues...    1.0   22     2
# 3  Taylor Cruz and Jordan Hayes are both integral...    6.0   21     2
# 4  Dr. Jordan Hayes is a key member of the Parano...    2.0   21     2
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["reports"].head()
# Out:
#   id                                              title  \
# 0  0  Dulce Base and the Paranormal Military Squad Team
#
#                                              content
# 0  # Dulce Base and the Paranormal Military Squad...

# %%
result.context_data["sources"].head()

# %%
if "claims" in result.context_data:
    print(result.context_data["claims"].head())
# Out:
#    id            entity object_id     status start_date end_date  \
# 0  12  DR. JORDAN HAYES      NONE       TRUE       NONE     NONE
# 1  13  DR. JORDAN HAYES      NONE  SUSPECTED       NONE     NONE
# 2  18  DR. JORDAN HAYES      ALEX       TRUE       NONE     NONE
# 3  49  DR. JORDAN HAYES      NONE  SUSPECTED       NONE     NONE
# 4  74  DR. JORDAN HAYES      NONE  SUSPECTED       NONE     NONE
#
#                                          description  in_context
# 0  Dr. Jordan Hayes contemplates their skepticism...        True
# 1  Dr. Jordan Hayes mused over the layers of data...        True
# 2  Dr. Jordan Hayes and Alex discovered a panel h...        True
# 3  Dr. Jordan Hayes was focused on deciphering al...        True
# 4  Dr. Jordan Hayes is analyzing the evolving ali...        True

# %% [markdown]
# ### Question Generation

# %% [markdown]
# This function takes a list of user queries and generates the next candidate questions.

# %%
question_generator = LocalQuestionGen(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
)

# %%
question_history = [
    "Tell me about Agent Mercer",
    "What happens in Dulce military base?",
]
candidate_questions = await question_generator.agenerate(
    question_history=question_history, context_data=None, question_count=5
)
print(candidate_questions.response)
# Out:
# ['- What is the primary objective of Operation: Dulce?', '- Who are the key members of the Paranormal Military Squad involved in Operation: Dulce?', '- How does Alex Mercer contribute to the mission at Dulce Base?', "- What role does the Dulce Military Base play in the team's efforts to communicate with extraterrestrial intelligence?", '- What challenges does the Paranormal Military Squad face at the Dulce Military Base?']
